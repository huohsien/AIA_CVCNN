# %%
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint

import matplotlib.pyplot as plt
import os
import time

batch_size = 128
num_classes = 10
epochs = 100
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# The data, shuffled and split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# build our CNN model
model = Sequential()
model.add(Conv2D(64, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

print(model.summary())

# initiate Adam optimizer
opt = keras.optimizers.Adam()

# Let's train the model using Adam
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255.
x_test /= 255.


print('Using real-time data augmentation.')
# This will do preprocessing and realtime data augmentation:
datagen = ImageDataGenerator(
    rotation_range=30,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False)  # randomly flip images

# Use ModelCheckpoint to save model and weights
if os.path.exists(save_dir):
    timestamp = 'saved_models_{:d}'.format(int(time.time()))
    print("file or directory with the name of ", save_dir, ' exists. use modified name : ', timestamp)
    save_dir = os.path.join(os.getcwd(), timestamp)
    os.makedirs(save_dir)
else:
    os.makedirs(save_dir)

model_path = os.path.join(save_dir, model_name)
print('model_path= ', model_path)
checkpoint = ModelCheckpoint(model_path, monitor='val_loss', save_best_only=True, verbose=1)

# earlystop
earlystop = EarlyStopping(monitor='val_loss', patience=5, verbose=1)

# Fit the model on the batches generated by datagen.flow().
model_history = model.fit_generator(datagen.flow(x_train, y_train,
                                 batch_size=batch_size),
                    epochs=epochs,
                    validation_data=(x_test, y_test),
                    workers=4,
                    callbacks=[earlystop,checkpoint])

# loading our save model
print("Loading trained model")
model = load_model(model_path)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 128)       73856
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 30, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 15, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 64)        73792
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_6 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,371,658
# Trainable params: 1,371,658
# Non-trainable params: 0
# _________________________________________________________________
# None
# Using real-time data augmentation.
# file or directory with the name of  /home/jovyan/CVCNN (part1-4)/part3/02_cnn_in_keras/saved_models  exists. use modified name :  saved_models_1555998016
# model_path=  /home/jovyan/CVCNN (part1-4)/part3/02_cnn_in_keras/saved_models_1555998016/keras_cifar10_trained_model.h5
# Epoch 1/100
# 391/391 [==============================] - 21s 54ms/step - loss: 1.6783 - acc: 0.3813 - val_loss: 1.2441 - val_acc: 0.5512
#
# Epoch 00001: val_loss improved from inf to 1.24410, saving model to /home/jovyan/CVCNN (part1-4)/part3/02_cnn_in_keras/saved_models_1555998016/keras_cifar10_trained_model.h5
# Epoch 2/100
# 391/391 [==============================] - 19s 49ms/step - loss: 1.3609 - acc: 0.5098 - val_loss: 1.1539 - val_acc: 0.5773
#
# Epoch 00002: val_loss improved from 1.24410 to 1.15388, saving model to /home/jovyan/CVCNN (part1-4)/part3/02_cnn_in_keras/saved_models_1555998016/keras_cifar10_trained_model.h5
# Epoch 3/100
# 391/391 [==============================] - 19s 49ms/step - loss: 1.2200 - acc: 0.5650 - val_loss: 1.0445 - val_acc: 0.6308
#
# Epoch 00003: val_loss improved from 1.15388 to 1.04446, saving model to /home/jovyan/CVCNN (part1-4)/part3/02_cnn_in_keras/saved_models_1555998016/keras_cifar10_trained_model.h5
# Epoch 4/100
# 391/391 [==============================] - 19s 49ms/step - loss: 1.1339 - acc: 0.5964 - val_loss: 1.0946 - val_acc: 0.6237
#
# Epoch 00004: val_loss did not improve from 1.04446
# Epoch 5/100
# 391/391 [==============================] - 19s 49ms/step - loss: 1.0807 - acc: 0.6180 - val_loss: 0.9977 - val_acc: 0.6500
#
# Epoch 00005: val_loss improved from 1.04446 to 0.99770, saving model to /home/jovyan/CVCNN (part1-4)/part3/02_cnn_in_keras/saved_models_1555998016/keras_cifar10_trained_model.h5
# Epoch 6/100
# 391/391 [==============================] - 19s 49ms/step - loss: 1.0315 - acc: 0.6357 - val_loss: 1.0037 - val_acc: 0.6566
#
# Epoch 00006: val_loss did not improve from 0.99770
# Epoch 7/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.9873 - acc: 0.6533 - val_loss: 0.8783 - val_acc: 0.6939
#
# Epoch 00007: val_loss improved from 0.99770 to 0.87834, saving model to /home/jovyan/CVCNN (part1-4)/part3/02_cnn_in_keras/saved_models_1555998016/keras_cifar10_trained_model.h5
# Epoch 8/100
# 391/391 [==============================] - 19s 48ms/step - loss: 0.9517 - acc: 0.6644 - val_loss: 0.7922 - val_acc: 0.7295
#
# Epoch 00008: val_loss improved from 0.87834 to 0.79222, saving model to /home/jovyan/CVCNN (part1-4)/part3/02_cnn_in_keras/saved_models_1555998016/keras_cifar10_trained_model.h5
# Epoch 9/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.9300 - acc: 0.6735 - val_loss: 0.8150 - val_acc: 0.7128
#
# Epoch 00009: val_loss did not improve from 0.79222
# Epoch 10/100
# 391/391 [==============================] - 19s 48ms/step - loss: 0.9086 - acc: 0.6814 - val_loss: 0.8312 - val_acc: 0.7111
#
# Epoch 00010: val_loss did not improve from 0.79222
# Epoch 11/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.8876 - acc: 0.6899 - val_loss: 0.7630 - val_acc: 0.7350
#
# Epoch 00011: val_loss improved from 0.79222 to 0.76298, saving model to /home/jovyan/CVCNN (part1-4)/part3/02_cnn_in_keras/saved_models_1555998016/keras_cifar10_trained_model.h5
# Epoch 12/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.8677 - acc: 0.6968 - val_loss: 0.8733 - val_acc: 0.7038
#
# Epoch 00012: val_loss did not improve from 0.76298
# Epoch 13/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.8570 - acc: 0.7008 - val_loss: 0.7908 - val_acc: 0.7259
#
# Epoch 00013: val_loss did not improve from 0.76298
# Epoch 14/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.8375 - acc: 0.7081 - val_loss: 0.7256 - val_acc: 0.7490
#
# Epoch 00014: val_loss improved from 0.76298 to 0.72565, saving model to /home/jovyan/CVCNN (part1-4)/part3/02_cnn_in_keras/saved_models_1555998016/keras_cifar10_trained_model.h5
# Epoch 15/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.8306 - acc: 0.7094 - val_loss: 0.7008 - val_acc: 0.7598
#
# Epoch 00015: val_loss improved from 0.72565 to 0.70080, saving model to /home/jovyan/CVCNN (part1-4)/part3/02_cnn_in_keras/saved_models_1555998016/keras_cifar10_trained_model.h5
# Epoch 16/100
# 391/391 [==============================] - 19s 48ms/step - loss: 0.8152 - acc: 0.7157 - val_loss: 0.7169 - val_acc: 0.7501
#
# Epoch 00016: val_loss did not improve from 0.70080
# Epoch 17/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.8136 - acc: 0.7176 - val_loss: 0.6676 - val_acc: 0.7757
#
# Epoch 00017: val_loss improved from 0.70080 to 0.66761, saving model to /home/jovyan/CVCNN (part1-4)/part3/02_cnn_in_keras/saved_models_1555998016/keras_cifar10_trained_model.h5
# Epoch 18/100
# 391/391 [==============================] - 19s 48ms/step - loss: 0.8010 - acc: 0.7208 - val_loss: 0.6411 - val_acc: 0.7794
#
# Epoch 00018: val_loss improved from 0.66761 to 0.64115, saving model to /home/jovyan/CVCNN (part1-4)/part3/02_cnn_in_keras/saved_models_1555998016/keras_cifar10_trained_model.h5
# Epoch 19/100
# 391/391 [==============================] - 19s 48ms/step - loss: 0.7887 - acc: 0.7256 - val_loss: 0.6624 - val_acc: 0.7735
#
# Epoch 00019: val_loss did not improve from 0.64115
# Epoch 20/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.7767 - acc: 0.7303 - val_loss: 0.7096 - val_acc: 0.7606
#
# Epoch 00020: val_loss did not improve from 0.64115
# Epoch 21/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.7704 - acc: 0.7305 - val_loss: 0.6617 - val_acc: 0.7712
#
# Epoch 00021: val_loss did not improve from 0.64115
# Epoch 22/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.7653 - acc: 0.7337 - val_loss: 0.6420 - val_acc: 0.7789
#
# Epoch 00022: val_loss did not improve from 0.64115
# Epoch 23/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.7539 - acc: 0.7369 - val_loss: 0.6569 - val_acc: 0.7782
#
# Epoch 00023: val_loss did not improve from 0.64115
# Epoch 00023: early stopping
# Loading trained model
# 10000/10000 [==============================] - 1s 84us/step
# Test loss: 0.6411479446411132
# Test accuracy: 0.7794

# %%
training_loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

plt.plot(training_loss, label="training_loss")
plt.plot(val_loss, label="validation_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Learning Curve")
plt.legend(loc='best')
plt.show()
